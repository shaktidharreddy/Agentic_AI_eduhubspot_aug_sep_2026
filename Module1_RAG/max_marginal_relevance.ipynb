# %% [markdown]
# <a href="https://colab.research.google.com/github/shaktidharreddy/Agentic_AI_eduhubspot_aug_sep_2026/blob/main/Module1_RAG/max_marginal_relevance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_community langchain_core langchain_openai chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.8/571.8 kB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 106.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.3 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

# Retrieve the API key from Colab secrets and set as environment variable
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %%
from langchain_core.documents import Document
from langchain_community.vectorstores import Chroma
# from langchain_huggingface import HuggingFaceEmbeddings
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

docs = [
    Document(page_content="The capital of France is Paris", metadata={"source": "source2"}),
    Document(page_content="France caputal is Paris", metadata={"source": "source3"}),
    Document(page_content="Paris is capital of France", metadata={"source": "source4"}),
    Document(page_content="The capital of Spain is Madrid", metadata={"source": "source5"}),
    Document(page_content="The capital of Portugal is Lisbon", metadata={"source": "source6"}),
    Document(page_content="The capital of Greece is Athens", metadata={"source": "source7"}),
]

# vectorstore = Chroma.from_documents(docs, HuggingFaceEmbeddings())
vectorstore = Chroma.from_documents(docs, OpenAIEmbeddings())
similarity_retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 3})

mmr_retriever = vectorstore.as_retriever(search_type="mmr", search_kwargs={"k": 3})

print("-"*100)
print("Similarity Retriever:")
print(similarity_retriever.invoke("What is the capital of France?"))
print("-"*100)
print("MMR Retriever:")
print(mmr_retriever.invoke("What is the capital of France?"))
print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Similarity Retriever:
# [Document(metadata={'source': 'source2'}, page_content='The capital of France is Paris'), Document(metadata={'source': 'source4'}, page_content='Paris is capital of France'), Document(metadata={'source': 'source3'}, page_content='France caputal is Paris')]
# ----------------------------------------------------------------------------------------------------
# MMR Retriever:
# [Document(metadata={'source': 'source2'}, page_content='The capital of France is Paris'), Document(metadata={'source': 'source5'}, page_content='The capital of Spain is Madrid'), Document(metadata={'source': 'source6'}, page_content='The capital of Portugal is Lisbon')]
# ----------------------------------------------------------------------------------------------------
